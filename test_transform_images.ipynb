# %%
from learning.image_transformer import ImageTransformer

# %%
it = ImageTransformer()
path_to_sentence = "data/example/Roboto Condensed/1606745034.6655488.png"

# %%
it.sentence_to_image(path_to_sentence)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x64 at 0x7F9DAD86F5D0>

# %%
it.sentence_to_image(path_to_sentence)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x64 at 0x7F9DAD86FE90>

# %%
it.sentence_to_image(path_to_sentence)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x64 at 0x7F9DAD86F510>

# %%
it.sentence_to_image(path_to_sentence)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x64 at 0x7F9DAD878C10>
