# %%
from learning.image_transformer import ImageTransformer

it = ImageTransformer(square_dim=300)
img = it.sentence_to_image("data/10_fonts_100_sentences/Castoro/1606822242.6618695.png")
img
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F6006390D90>

# %%
img2 = it.sentence_to_image("data/10_fonts_100_sentences/Castoro/1606822242.6618695.png")
img2
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F601419A0A0>

# %%
img3 = it.sentence_to_image("data/10_fonts_100_sentences/Castoro/1606822242.6618695.png")
img3
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F6014190280>
